# %% [markdown]
# # Python Exception Handling – Comprehensive Guide
#
# This notebook covers Python exception handling in depth, including:
#
# 1. What exceptions are
# 2. Basic try/except
# 3. Multiple exceptions
# 4. else and finally blocks
# 5. Built-in exceptions
# 6. Raising exceptions
# 7. Custom exceptions
# 8. Exception chaining
# 9. Assertions
# 10. Best practices
# 11. Practical examples

# %% [markdown]
# ## 1. What is an Exception?

# %%
x = 10
y = 0

# This will raise ZeroDivisionError
result = x / y
print(result)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 5
#       2 y = 0
#       4 # This will raise ZeroDivisionError
# ----> 5 result = x / y
#       6 print(result)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# Exceptions stop program execution unless handled.

# %% [markdown]
# ## 2. Basic try / except

# %%
try:
    x = 10
    y = 0
    result = x / y
except ZeroDivisionError:
    print('Cannot divide by zero')
# Out:
# Cannot divide by zero

# %% [markdown]
# ## 3. Catching Multiple Exceptions

# %%
try:
    num = int('abc')
    value = 10 / num
except ValueError:
    print('Conversion failed')
except ZeroDivisionError:
    print('Division by zero')
# Out:
# Conversion failed

# %% [markdown]
# ## 4. Handling Multiple Exceptions Together

# %%
try:
    num = int('abc')
except (ValueError, TypeError):
    print('Invalid conversion')
# Out:
# Invalid conversion

# %% [markdown]
# ## 5. Using else Block

# %%
try:
    num = int('5')
except ValueError:
    print('Conversion failed')
else:
    print('Conversion successful:', num)
# Out:
# Conversion successful: 5

# %% [markdown]
# ## 6. Using finally Block

# %%
try:
    f = open('sample.txt')
except FileNotFoundError:
    print('File not found')
finally:
    print('Execution completed')
# Out:
# File not found
# Execution completed

# %% [markdown]
# ## 7. Getting Exception Information

# %%
try:
    num = int('abc')
except Exception as e:
    print('Error occurred:', e)

# %% [markdown]
# ## 8. Raising Exceptions

# %%
age = -5

if age < 0:
    raise ValueError('Age cannot be negative')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 4
#       1 age = -5
#       3 if age < 0:
# ----> 4     raise ValueError('Age cannot be negative')
#
# ValueError: Age cannot be negative

# %% [markdown]
# ## 9. Custom Exceptions

# %%
class InsufficientBalanceError(Exception):
    pass

def withdraw(balance, amount):
    if amount > balance:
        raise InsufficientBalanceError('Not enough balance')
    return balance - amount

withdraw(1000, 2000)
# Out:
# ---------------------------------------------------------------------------
# InsufficientBalanceError                  Traceback (most recent call last)
# Cell In[8], line 9
#       6         raise InsufficientBalanceError('Not enough balance')
#       7     return balance - amount
# ----> 9 withdraw(1000, 2000)
#
# Cell In[8], line 6, in withdraw(balance, amount)
#       4 def withdraw(balance, amount):
#       5     if amount > balance:
# ----> 6         raise InsufficientBalanceError('Not enough balance')
#       7     return balance - amount
#
# InsufficientBalanceError: Not enough balance

# %% [markdown]
# ## 10. Exception Chaining
#
# Exception chaining means linking one exception to another so that Python shows the original cause of the error along with the new exception.
#
# This is useful when you catch an exception and raise another exception, but still want to preserve the original error information.

# %%
try:
    num = int('abc')
except ValueError as e:
    raise RuntimeError('Conversion failed') from e
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 try:
# ----> 2     num = int('abc')
#       3 except ValueError as e:
#
# ValueError: invalid literal for int() with base 10: 'abc'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 4
#       2     num = int('abc')
#       3 except ValueError as e:
# ----> 4     raise RuntimeError('Conversion failed') from e
#
# RuntimeError: Conversion failed

# %% [markdown]
# ## 11. Assertions

# %%
x = 5
assert x > 0
print('Assertion passed')

# %% [markdown]
# ## 12. Best Practices
#
# - Catch specific exceptions instead of generic ones
# - Avoid bare except blocks
# - Use finally for cleanup operations
# - Log exceptions in production systems
# - Create custom exceptions for domain errors
